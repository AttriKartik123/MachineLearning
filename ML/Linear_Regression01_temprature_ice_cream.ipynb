# %%
import numpy as np
# Step 1: Prepare the Data (Temperature in °C and Ice Cream Sales in Rs)
temperature = np.array([20, 25, 30, 35, 40, 45]).reshape(-1, 1)  # Temperature in °C
sales = np.array([200, 250, 400, 450, 600, 650])  # Ice Cream Sales in Rs

# %%
temperature
# Out:
# array([[20],
#        [25],
#        [30],
#        [35],
#        [40],
#        [45]])

# %%
sales
# Out:
# array([200, 250, 400, 450, 600, 650])

# %%
import pandas as pd

# %%
df=pd.Series(temperature.flatten(),sales)
df
# Out:
# 200    20
# 250    25
# 400    30
# 450    35
# 600    40
# 650    45
# dtype: int64

# %%
from sklearn.linear_model import LinearRegression

# %%
# Step 2: Train the Linear Regression Model
model = LinearRegression()
model.fit(temperature, sales)
# Out:
# LinearRegression()

# %%
model
# Out:
# LinearRegression()

# %%
# Step 3: Make Predictions
predicted_sales = model.predict(temperature)
predicted_sales
# Out:
# array([185.71428571, 281.42857143, 377.14285714, 472.85714286,
#        568.57142857, 664.28571429])

# %%
import matplotlib.pyplot as plt

# %%
# Step 4: Visualize the Regression Line
plt.scatter(temperature, sales, color='blue', label="Actual Sales")  # Data points
plt.plot(temperature, predicted_sales, color='red', linestyle='--', label="Regression Line")  # Best fit line
# Labels and Title
plt.xlabel("Temperature (°C)")
plt.ylabel("Ice Cream Sales (Rs)")
plt.title("Temperature vs Ice Cream Sales Prediction")
plt.legend()

# Show Plot
plt.show()

# %%
newvalues=np.array([21,32,34,41,42,51]).reshape(-1, 1)
newvalues
# Out:
# array([[21],
#        [32],
#        [34],
#        [41],
#        [42],
#        [51]])

# %%
predicted_sales = model.predict(newvalues)
predicted_sales
# Out:
# array([204.85714286, 415.42857143, 453.71428571, 587.71428571,
#        606.85714286, 779.14285714])

# %%
import matplotlib.pyplot as plt

# %%
# Step 4: Visualize the Regression Line
plt.scatter(temperature, sales, color='blue', label="Actual Sales")  # Data points
plt.plot(temperature, predicted_sales, color='red', linestyle='--', label="Regression Line")  # Best fit line
# Labels and Title
plt.xlabel("Temperature (°C)")
plt.ylabel("Ice Cream Sales (Rs)")
plt.title("Temperature vs Ice Cream Sales Prediction")
plt.legend()

# Show Plot
plt.show()
